# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"D:\HOUSE_PRICE_PREDICTION\data\House Prices.csv")
dataset.head(3)
# Out:
#    ID             Date     Price  Bedrooms  Bathrooms  Sqft_living  Sqft_lot  \
# 0   1  20140916T000000  280000.0         6       3.00         2400      9373
# 1   2  20150422T000000  300000.0         6       3.00         2400      9373
# 2   3  20140508T000000  647500.0         4       1.75         2060     26036
#
#    Floors  Waterfront  View  ...  Grade  Sqft_above  Sqft_basement  Yr_built  \
# 0     2.0           0     0  ...      7        2400              0      1991
# 1     2.0           0     0  ...      7        2400              0      1991
# 2     1.0           0     0  ...      8        1160            900      1947
#
#    Yr_renovated  zipcode      Lat     Long  Sqft_living15  Sqft_lot15
# 0             0    98002  47.3262 -122.214           2060        7316
# 1             0    98002  47.3262 -122.214           2060        7316
# 2             0    98166  47.4444 -122.351           2590       21891
#
# [3 rows x 21 columns]

# %%
dataset.drop(['ID', 'Date'], axis=1, inplace=True)

# %%
dataset['House_Age']=2025-dataset['Yr_built']
dataset['Was_Renovated']=dataset['Yr_renovated'].apply(lambda x:0 if x==0 else 1)
dataset['Total_Bathrooms']=dataset['Bathrooms']+0.5*dataset['Bedrooms']
dataset['Living_per_Lot']=dataset['Sqft_living']/dataset['Sqft_lot']
dataset['Total_Sqft'] = dataset['Sqft_living'] + dataset['Sqft_basement']

# %%
# Drop original columns we just transformed
dataset.drop(['Yr_built', 'Yr_renovated'], axis=1, inplace=True)

# %%
# 5. Encode categorical variable: zipcode (LabelEncoder or OneHot)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset['zipcode'] = le.fit_transform(dataset['zipcode'])

# %%
x = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# 9. Train model
lr = LinearRegression()
lr.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test_scaled)

# %%
print("Evaluation Metrics:")
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R² Score:', metrics.r2_score(y_test, y_pred))
# Out:
# Evaluation Metrics:
# MAE: 123835.55537951148
# MSE: 36096296733.22144
# RMSE: 189990.25431116577
# R² Score: 0.6983198543038245

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted House Prices")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.grid(True)
plt.show()

# %%
# 13. Coefficients (Feature Importance)
coef_dataset = pd.DataFrame(lr.coef_, x_train.columns, columns=['Coefficient'])
print("\nFeature Importances (Coefficients):")
print(coef_dataset.sort_values(by='Coefficient', ascending=False))
# Out:
# Feature Importances (Coefficients):
#                    Coefficient
# Grade            106981.812466
# Lat               83576.687577
# House_Age         78649.777785
# Sqft_above        74430.588409
# Sqft_living       66227.182575
# Waterfront        52260.709111
# Total_Sqft        50950.602312
# View              41838.984262
# Living_per_Lot    27405.778844
# Bathrooms         25479.128804
# Condition         17869.932453
# Sqft_living15     12470.122680
# Sqft_lot           8906.821585
# Was_Renovated      8429.824431
# Total_Bathrooms    1992.970616
# Sqft_basement      -944.305123
# Sqft_lot15        -8774.001317
# Floors           -12881.670682
# Long             -25547.315752
# zipcode          -36162.199714
# Bedrooms         -38580.438122

# %%
import matplotlib.pyplot as plt

coef_dataset_sorted = coef_dataset.sort_values(by='Coefficient', ascending=False)

plt.figure(figsize=(10,6))
plt.bar(coef_dataset_sorted.index, coef_dataset_sorted['Coefficient'])
plt.xticks(rotation=45, ha='right')
plt.xlabel('Features')
plt.ylabel('Coefficient Value')
plt.title('Feature Importance Based on Linear Regression Coefficients')
plt.tight_layout()
plt.show()

# %%
import joblib
joblib.dump(lr, 'house_price_model.pkl')

# After fitting the scaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
